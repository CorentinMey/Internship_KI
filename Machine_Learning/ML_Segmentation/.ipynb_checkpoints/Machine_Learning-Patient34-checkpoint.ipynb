# %% [markdown]
# Python module to perform machine learning on the ST data and to visualize the results. This script was used on the 4 slides of patient 34. The segmentation was made with Stardist.

# %% [markdown]
# # Import

# %%
import anndata as ad
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import seaborn as sns
from seaborn import objects as so
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.image as mpimg

# %% [markdown]
# # Input

# %% [markdown]
# An AnnData object containing a dataset where each row is a tile and each column is a feature (extracted from the image by segmentation). The AnnData object contains also a obs where you can find pathologist's annotation and the path to each tile. Moreover, you can find the segmentation data processed with a PCA in the obsm part of the AnnData object.

# %%
adata1 = ad.read_h5ad('/disk2/user/cormey/outputs/Segmentation_objects/034_RJ.A1.h5ad')
adata2 = ad.read_h5ad('/disk2/user/cormey/outputs/Segmentation_objects/034_RJ.B1.h5ad')
adata3 = ad.read_h5ad('/disk2/user/cormey/outputs/Segmentation_objects/034_RJ.C1.h5ad')
adata4 = ad.read_h5ad('/disk2/user/cormey/outputs/Segmentation_objects/034_RJ.D1.h5ad')

# %%
#Combine in one dataset
adata = ad.concat([adata1, adata2, adata3, adata4])
# Out:
# /disk2/user/cormey/environments/test_env/lib/python3.12/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %% [markdown]
# # Output

# %% [markdown]
# Some graphs to visualize the performance of the machine learning and the quality of the features extracted by segmentation

# %% [markdown]
# # Visualize the AnnData object

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 8619 × 27
#     obs: 'path', 'annotation'
#     obsm: 'X_pca'

# %%
print(adata.var_names)
# Out:
# Index(['segmented_label', 'segmented_area_mean', 'segmented_area_std',
#        'segmented_bbox_area_mean', 'segmented_bbox_area_std',
#        'segmented_convex_area_mean', 'segmented_convex_area_std',
#        'segmented_eccentricity_mean', 'segmented_eccentricity_std',
#        'segmented_equivalent_diameter_mean',
#        'segmented_equivalent_diameter_std', 'segmented_euler_number_mean',
#        'segmented_euler_number_std', 'segmented_extent_mean',
#        'segmented_extent_std', 'segmented_feret_diameter_max_mean',
#        'segmented_feret_diameter_max_std', 'segmented_major_axis_length_mean',
#        'segmented_major_axis_length_std', 'segmented_minor_axis_length_mean',
#        'segmented_minor_axis_length_std', 'segmented_orientation_mean',
#        'segmented_orientation_std', 'segmented_perimeter_mean',
#        'segmented_perimeter_std', 'segmented_solidity_mean',
#        'segmented_solidity_std'],
#       dtype='object')

# %%
adata.obs.head()
# Out:
#                                                 path annotation
# 0  /disk2/user/cormey/outputs/Tilted_images/034_R...      Mixed
# 1  /disk2/user/cormey/outputs/Tilted_images/034_R...      Mixed
# 2  /disk2/user/cormey/outputs/Tilted_images/034_R...      Mixed
# 3  /disk2/user/cormey/outputs/Tilted_images/034_R...      Mixed
# 4  /disk2/user/cormey/outputs/Tilted_images/034_R...     Stroma

# %%
print(adata.X[:10, :20])
# Out:
# [[5.00000000e+00 1.52300000e+03 6.10733002e+02 2.24200000e+03
#   8.35714784e+02 1.58840000e+03 6.04153490e+02 7.01734908e-01
#   1.90161659e-01 4.32335633e+01 8.36676955e+00 1.00000000e+00
#   0.00000000e+00 6.79861083e-01 6.70645813e-02 5.61602219e+01
#   8.08884910e+00 5.41651261e+01 9.81742946e+00 3.57824548e+01]
#  [1.00000000e+00 5.30000000e+02 0.00000000e+00 6.80000000e+02
#   0.00000000e+00 5.42000000e+02 0.00000000e+00 7.82415302e-01
#   0.00000000e+00 2.59772392e+01 0.00000000e+00 1.00000000e+00
#   0.00000000e+00 7.79411765e-01 0.00000000e+00 3.51140997e+01
#   0.00000000e+00 3.39571051e+01 0.00000000e+00 2.11470253e+01]
#  [1.00000000e+00 9.97000000e+02 0.00000000e+00 1.41900000e+03
#   0.00000000e+00 1.02100000e+03 0.00000000e+00 7.32315893e-01
#   0.00000000e+00 3.56289184e+01 0.00000000e+00 1.00000000e+00
#   0.00000000e+00 7.02607470e-01 0.00000000e+00 4.86004115e+01
#   0.00000000e+00 4.47572622e+01 0.00000000e+00 3.04781324e+01]
#  [1.00000000e+00 6.65000000e+02 0.00000000e+00 8.64000000e+02
#   0.00000000e+00 6.90000000e+02 0.00000000e+00 8.04148209e-01
#   0.00000000e+00 2.90981837e+01 0.00000000e+00 1.00000000e+00
#   0.00000000e+00 7.69675926e-01 0.00000000e+00 3.93954312e+01
#   0.00000000e+00 3.86213629e+01 0.00000000e+00 2.29576523e+01]
#  [1.00000000e+00 3.71000000e+02 0.00000000e+00 4.94000000e+02
#   0.00000000e+00 3.88000000e+02 0.00000000e+00 7.67315751e-01
#   0.00000000e+00 2.17341177e+01 0.00000000e+00 1.00000000e+00
#   0.00000000e+00 7.51012146e-01 0.00000000e+00 2.78567766e+01
#   0.00000000e+00 2.74581784e+01 0.00000000e+00 1.76080916e+01]
#  [6.00000000e+00 7.56666667e+02 4.76241769e+02 1.27383333e+03
#   8.73145734e+02 7.92500000e+02 4.94125743e+02 8.76916107e-01
#   7.38321973e-02 2.96189109e+01 9.28105814e+00 1.00000000e+00
#   0.00000000e+00 6.28715392e-01 1.03593841e-01 4.47348339e+01
#   1.53664561e+01 4.55165344e+01 1.62992837e+01 1.97160841e+01]
#  [4.00000000e+00 1.05775000e+03 3.38826929e+02 1.69300000e+03
#   7.57716636e+02 1.10325000e+03 3.68798980e+02 8.05530111e-01
#   9.80440517e-02 3.62623659e+01 5.64003065e+00 1.00000000e+00
#   0.00000000e+00 6.52092806e-01 8.16142312e-02 4.99438844e+01
#   1.20045164e+01 5.01326577e+01 1.33711530e+01 2.70055570e+01]
#  [4.00000000e+00 2.02075000e+03 4.01666762e+02 2.99325000e+03
#   8.89504743e+02 2.08275000e+03 4.29117335e+02 7.39371615e-01
#   1.28316981e-01 5.04761477e+01 5.00572931e+00 1.00000000e+00
#   0.00000000e+00 7.00399618e-01 9.88421978e-02 6.63877655e+01
#   1.26753537e+01 6.56710436e+01 1.39145369e+01 4.01234193e+01]
#  [5.00000000e+00 8.80600000e+02 2.79376878e+02 1.27600000e+03
#   3.70884349e+02 9.09800000e+02 2.84375386e+02 7.13942732e-01
#   1.21782496e-01 3.30881967e+01 5.13672877e+00 1.00000000e+00
#   0.00000000e+00 6.96758699e-01 9.33757012e-02 4.20341777e+01
#   6.65792078e+00 4.14671005e+01 7.30107392e+00 2.70949597e+01]
#  [5.00000000e+00 1.04120000e+03 6.59858591e+02 1.38720000e+03
#   8.85006305e+02 1.06980000e+03 6.72685186e+02 7.33474322e-01
#   1.30452746e-01 3.46056426e+01 1.13201817e+01 1.00000000e+00
#   0.00000000e+00 7.54764133e-01 1.74531122e-02 4.44142741e+01
#   1.50987503e+01 4.36096229e+01 1.50088164e+01 2.79719845e+01]]

# %% [markdown]
# # Visualize the PCA

# %%
X=adata.X

# Create an PCA object with the number of wanted principal componants
pca = PCA(n_components=5)  # 5 PC

# Perform the PCA on the matrix X
reduced_features = pca.fit_transform(X)

# Check the results
print("Shape of reduced features:", reduced_features.shape)
# Out:
# Shape of reduced features: (8619, 5)

# %%
#See how much each components explain the total variance of the dataset

explained_variance_ratio = pca.explained_variance_ratio_

# Display results
for i, variance in enumerate(explained_variance_ratio):
    print(f"Principal component {i+1}: {variance:.2%} of the variance")
# Out:
# Principal component 1: 69.18% of the variance
# Principal component 2: 29.72% of the variance
# Principal component 3: 0.78% of the variance
# Principal component 4: 0.24% of the variance
# Principal component 5: 0.03% of the variance

# %%
#Visualize which variable are influencing the PC

# Stock the PC in a variable
loadings = pca.components_

# Convert the PC in a dataset to have a better readability
pc_loadings = pd.DataFrame(loadings.T, columns=[f'PC{i+1}' for i in range(loadings.shape[0])], index=adata.var_names)
print(pc_loadings)
# Out:
#                                              PC1           PC2       PC3  \
# segmented_label                    -2.905037e-03  8.987268e-03 -0.040370
# segmented_area_mean                 4.781741e-01 -1.321201e-01 -0.507978
# segmented_area_std                  1.437136e-01  4.839583e-01 -0.171869
# segmented_bbox_area_mean            6.711268e-01 -2.054132e-01  0.659639
# segmented_bbox_area_std             1.898480e-01  6.636667e-01  0.274117
# segmented_convex_area_mean          4.923544e-01 -1.333198e-01 -0.412352
# segmented_convex_area_std           1.438195e-01  4.966933e-01 -0.171113
# segmented_eccentricity_mean        -5.988523e-06 -2.274348e-05  0.000487
# segmented_eccentricity_std         -2.492875e-06  6.029674e-05 -0.000124
# segmented_equivalent_diameter_mean  8.067845e-03 -2.847327e-03 -0.007890
# segmented_equivalent_diameter_std   1.380594e-03  7.586789e-03 -0.000958
# segmented_euler_number_mean        -3.043465e-09  1.581304e-07  0.000065
# segmented_euler_number_std         -8.870426e-07  5.884962e-06  0.000110
# segmented_extent_mean              -5.036275e-07  6.314788e-06 -0.000510
# segmented_extent_std               -1.800970e-06  3.029087e-05  0.000111
# segmented_feret_diameter_max_mean   1.009170e-02 -4.739756e-03  0.015153
# segmented_feret_diameter_max_std    1.433980e-03  9.054189e-03  0.005685
# segmented_major_axis_length_mean    1.001478e-02 -4.914662e-03  0.016897
# segmented_major_axis_length_std     1.453616e-03  8.948183e-03  0.007652
# segmented_minor_axis_length_mean    6.593567e-03 -1.481049e-03 -0.020519
# segmented_minor_axis_length_std     1.297990e-03  6.540684e-03 -0.005987
# segmented_orientation_mean         -5.626166e-05 -4.304915e-05  0.000303
# segmented_orientation_std          -2.220225e-05  3.480835e-04 -0.000584
# segmented_perimeter_mean            2.827322e-02 -1.095584e-02  0.007757
# segmented_perimeter_std             4.391940e-03  2.611254e-02  0.005045
# segmented_solidity_mean             3.949000e-06 -4.687864e-06 -0.000099
# segmented_solidity_std             -5.231517e-07  1.692541e-05  0.000072
#
#                                          PC4       PC5
# segmented_label                     0.013271  0.971907
# segmented_area_mean                 0.220338 -0.161381
# segmented_area_std                 -0.528363  0.029235
# segmented_bbox_area_mean           -0.253609  0.017461
# segmented_bbox_area_std             0.664102  0.004686
# segmented_convex_area_mean          0.141515  0.139781
# segmented_convex_area_std          -0.382012 -0.049931
# segmented_eccentricity_mean        -0.000222 -0.001293
# segmented_eccentricity_std          0.000013  0.001326
# segmented_equivalent_diameter_mean  0.005065  0.022452
# segmented_equivalent_diameter_std  -0.005611  0.002437
# segmented_euler_number_mean        -0.000069  0.000127
# segmented_euler_number_std         -0.000100  0.000521
# segmented_extent_mean               0.000350  0.000109
# segmented_extent_std               -0.000072  0.000545
# segmented_feret_diameter_max_mean  -0.005538 -0.013735
# segmented_feret_diameter_max_std    0.012623  0.001165
# segmented_major_axis_length_mean   -0.005135 -0.022223
# segmented_major_axis_length_std     0.012092  0.004132
# segmented_minor_axis_length_mean    0.009125  0.048739
# segmented_minor_axis_length_std    -0.011814  0.013150
# segmented_orientation_mean         -0.000510 -0.001344
# segmented_orientation_std           0.000230  0.006319
# segmented_perimeter_mean           -0.002058  0.048280
# segmented_perimeter_std             0.012309  0.001671
# segmented_solidity_mean             0.000106 -0.000159
# segmented_solidity_std             -0.000097  0.000731

# %%
# Extract the first two principal components
pc1 = adata.obsm['X_pca'][:, 0]
pc2 = adata.obsm['X_pca'][:, 1]

# Stock the annotation in a variable
labels = adata.obs['annotation']

# Scatter plot of the first two principal components
plt.figure(figsize=(10, 7))
sns.scatterplot(x=pc1, y=pc2, hue=labels, palette='Set1')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA - Projection onto the first two principal components colored by annotation')
plt.legend(title='Annotation')
plt.show()

# Explained variance by each principal component
explained_variance = pca.explained_variance_ratio_

# Create the explained variance plot
plt.figure(figsize=(10, 7))
plt.bar(range(1, len(explained_variance) + 1), explained_variance)
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance')
plt.title('Explained Variance by Each Principal Component')
plt.show()

# %% [markdown]
# # Perform the Machine Learning

# %%
##Perform a machine learning algorithm on the segmented dataset

labels = adata.obs["annotation"]  # Extraction of pathologist's annotation
image_paths = adata.obs["path"]

# Extract segmentation features and annotation
X = adata.X
y = labels

# Split data in a train dataset and a test dataset
X_train, X_test, y_train, y_test, paths_train, paths_test = train_test_split(X, y, image_paths, test_size=0.3, random_state=42)

# Train the classification model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict on the test dataset
y_pred = model.predict(X_test)

# Display the classification report
print(classification_report(y_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
# Benign breast       0.00      0.00      0.00       112
#           Fat       0.00      0.00      0.00        24
#  Immune cells       0.00      0.00      0.00        49
#         Mixed       0.34      0.29      0.31       544
#           Out       0.00      0.00      0.00        23
#        Stroma       0.70      0.84      0.77       954
#         Tumor       0.71      0.79      0.74       880
#
#      accuracy                           0.64      2586
#     macro avg       0.25      0.27      0.26      2586
#  weighted avg       0.57      0.64      0.60      2586
# /disk2/user/cormey/environments/test_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /disk2/user/cormey/environments/test_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /disk2/user/cormey/environments/test_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
cm = confusion_matrix(y_test, y_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot()

# Adjust the rotation of the x-axis labels and y-axis labels
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=45)

# Adjust layout to ensure everything fits without overlapping
plt.tight_layout()

# %%
##Perform a machine learning algorithm on the segmented dataset (PCA version)

labels = adata.obs["annotation"]  # Extraction of pathologist's annotation

# Extract segmentation features and annotation
X = adata.obsm['X_pca']
y = labels

# Split data in a train dataset and a test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the classification model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict on the test dataset
y_pred = model.predict(X_test)

# Display the classification report
print(classification_report(y_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
# Benign breast       0.31      0.10      0.15       112
#           Fat       0.00      0.00      0.00        24
#  Immune cells       0.33      0.02      0.04        49
#         Mixed       0.31      0.26      0.29       544
#           Out       0.00      0.00      0.00        23
#        Stroma       0.67      0.76      0.71       954
#         Tumor       0.68      0.76      0.72       880
#
#      accuracy                           0.60      2586
#     macro avg       0.33      0.27      0.27      2586
#  weighted avg       0.56      0.60      0.57      2586

# %% [markdown]
# # Observe which parameters represent the most each types of cell

# %%
# Convert adata.X to a DataFrame and adata.obs to a DataFrame
data_df = pd.DataFrame(adata.X, columns=adata.var_names)
obs_df = adata.obs

# Combine the data with the information from `obs`
combined_df2 = pd.concat([data_df, obs_df.reset_index(drop=True)], axis=1)

# List of feature columns (excluding 'path' and 'annotation')
feature_columns = [col for col in combined_df2.columns if col not in ['path', 'annotation']]

# For each parameter
for feature in feature_columns:

    # Get mean and std values for each annotation
    mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
    std_by_annotation = combined_df2.groupby('annotation')[feature].std()
    
    # Convert the Series to DataFrames for easier manipulation
    mean_df = mean_by_annotation.reset_index()
    std_df = std_by_annotation.reset_index()
    
    # Merge the two DataFrames to have the means and standard deviations in the same DataFrame
    stats_df = pd.merge(mean_df, std_df, on='annotation')
    stats_df.columns = ['annotation', 'mean', 'std']
    
    # Create the bar plot with error bars
    plt.figure(figsize=(10, 6))
    plt.bar(stats_df['annotation'], stats_df['mean'], yerr=stats_df['std'], color='skyblue', capsize=5)
    plt.xlabel('Annotation')
    plt.ylabel('Mean of {}'.format(feature))
    plt.title('{}, Mean in Function of Annotations'.format(feature))
    plt.xticks(rotation=45)
    plt.tight_layout()
    
    # Show the plot
    plt.show()
# Out:
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
# /tmp/ipykernel_2644767/485548206.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_by_annotation = combined_df2.groupby('annotation')[feature].mean()
# /tmp/ipykernel_2644767/485548206.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_by_annotation = combined_df2.groupby('annotation')[feature].std()
